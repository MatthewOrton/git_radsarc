# %% [markdown]
# # Retroperitoneal sarcoma radiomics study
# # Prediction of tumour type and grade
# # Logistic regression with group selection

# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 500, 'display.max_rows', 500, 'display.precision', 3)
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegressionCV, LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import roc_auc_score, make_scorer
from sklearn.pipeline import Pipeline
from sklearn.model_selection import KFold, StratifiedKFold, RepeatedStratifiedKFold, GridSearchCV
from sklearn.model_selection import cross_validate
import os, warnings, copy, sys, shutil
import matplotlib.pyplot as plt
import pickle
from time import strftime, localtime
from pyirr import intraclass_correlation
from scipy.stats import skew
import seaborn as sns
from scipy.stats import mannwhitneyu

rootFolder = os.path.join(os.path.expanduser("~"), 'Dicom Files/RADSARC_R')

# this module should be in the same folder as this notebook
from fit_LR_groupSelection_correlationThresholds import fit_LR_groupSelection_correlationThresholds, plotResultExperiments, displayOneExperiment

n_splits = 10
n_repeats = 50
thresholds = np.round(np.arange(0.6,1.00001,0.02), 2)
penalty = 'l1'

displayAll = True

# %% [markdown]
# ## Create output and copy code

# %%
# %%capture out_stream

# set output folder to None if this is a fresh run
# set output folder to an existing location to load pre-saved results from there
outputFolder = None #'/Users/morton/Dicom Files/RADSARC_R/XNAT/experiments/LR_GroupSelection__20220924_0958'

if outputFolder is None:
    
    saveOutputs = True
    
    outputFolder = os.path.join(rootFolder, 'XNAT/experiments/LR_GroupSelection__' + strftime("%Y%m%d_%H%M", localtime()))
    os.mkdir(outputFolder)
    os.mkdir(os.path.join(outputFolder, 'code'))
    os.mkdir(os.path.join(outputFolder, 'figures'))
    
    jupyterFile = os.path.join(os.path.abspath(""), 'LR_GroupSelection_withValidation.ipynb')
    shutil.copyfile(jupyterFile, os.path.join(outputFolder, 'code', 'LR_GroupSelection_withValidation.ipynb'))

    file1 = os.path.join(os.path.abspath(""), 'fit_LR_groupSelection_correlationThresholds.py')
    shutil.copyfile(file1, os.path.join(outputFolder, 'code', 'fit_LR_groupSelection_correlationThresholds.py'))

    user = os.path.expanduser("~")
    file2 = os.path.join(user, 'Documents/git/git_icrpythonradiomics/machineLearning/featureSelection.py')
    shutil.copyfile(file2, os.path.join(outputFolder, 'code', 'featureSelection.py'))

else:
    
    saveOutputs = False

# %% [markdown]
# ### Utility functions

# %%
def groupStrsDisp(strGroups):
    
    def tidyGroup(strGroup):
        if strGroup == '':
            strGroup = 'all'
        strGroup = strGroup.replace('glcm|gldm|glszm|glrlm|ngtdm','texture')
        strGroup = strGroup.replace('firstorder|histogram','firstorder')
        return strGroup

    if isinstance(strGroups, str):
        return tidyGroup(strGroups)
    
    if isinstance(strGroups, list):
        return [tidyGroup(x) for x in strGroups]

# %% [markdown]
# ## Load data

# %%
# open clinical spreadsheet
clinicalSpreadsheet = os.path.join(rootFolder, 'ClinicalData', 'Clinical data for analysis.xlsx')
dfClinical = pd.read_excel(clinicalSpreadsheet, sheet_name='220818_Completed segs', header = 2, skiprows=[3], nrows=170, engine='openpyxl')
dfClinical.sort_values('Anon Code', inplace=True, ignore_index=True)

dfClinical['Grade_1_234'] = dfClinical[' Grade']==1
dfClinical['Grade_12_34'] = dfClinical[' Grade']<=2
dfClinical = dfClinical[['Anon Code', 'Grade_1_234', 'Grade_12_34', 'subtype']]

# TEST open clinical spreadsheet
clinicalSpreadsheetTest = os.path.join(rootFolder, 'ClinicalData', 'EORTC_Radsarc_Clindata.xlsx')
dfClinicalTest = pd.read_excel(clinicalSpreadsheetTest, sheet_name='Completed segs_for analysis', engine='openpyxl')
dfClinicalTest['Anon Code'] = ['EORTCRSRC_' + str(int(x)).zfill(3) for x in dfClinicalTest['PATID']]
dfClinicalTest['Grade_1_234'] = dfClinicalTest['grade']==1
dfClinicalTest['Grade_12_34'] = dfClinicalTest['grade']<=2
dfClinicalTest = dfClinicalTest[['Anon Code', 'Grade_1_234', 'Grade_12_34', 'subtype']]

# %%
def readRadData(folder):
    df = pd.read_csv(os.path.join(rootFolder, 'XNAT', 'extractions', folder, 'radiomicFeatures', 'radiomicFeatures.csv'))
    df.drop(list(df.filter(regex = 'source')), axis = 1, inplace = True)
    df.drop(list(df.filter(regex = 'diagnostic')), axis = 1, inplace = True)
    df.drop(list(df.filter(regex = 'histogram')), axis = 1, inplace = True)
    return df

# training
dfRad = readRadData('extractions__20221122_1628_allRegions_volFracApprox')

# reproducibility
dfRadRep = readRadData('extractions__20221122_2037_repro_volFracApprox')

# open test data
dfRadTest = readRadData('extractions__20221125_0939_eortcTestData')

# %% [markdown]
# ## Compute ICCs and remove unreproducible features

# %%
dfRadOri = dfRad.copy()

subjectIDs = dfRadOri.merge(dfRadRep, on='StudyPatientName').StudyPatientName

# select rows and make sure they are both sorted on SubjectID
dfRadOri = dfRadOri.loc[dfRadOri['StudyPatientName'].isin(subjectIDs)]
dfRadOri.sort_values('StudyPatientName', axis=0, inplace=True)

dfRadRep = dfRadRep.loc[dfRadRep['StudyPatientName'].isin(subjectIDs)]
dfRadRep.sort_values('StudyPatientName', axis=0, inplace=True)

# remove high/mid/low_enhancing features
dfRadOri.drop(list(dfRadOri.filter(regex = 'low_enhancing_original')), axis = 1, inplace = True)
dfRadRep.drop(list(dfRadRep.filter(regex = 'low_enhancing_original')), axis = 1, inplace = True)
dfRadOri.drop(list(dfRadOri.filter(regex = 'mid_enhancing_original')), axis = 1, inplace = True)
dfRadRep.drop(list(dfRadRep.filter(regex = 'mid_enhancing_original')), axis = 1, inplace = True)
dfRadOri.drop(list(dfRadOri.filter(regex = 'high_enhancing_original')), axis = 1, inplace = True)
dfRadRep.drop(list(dfRadRep.filter(regex = 'high_enhancing_original')), axis = 1, inplace = True)

# remove these features
dfRadOri.drop(list(dfRadOri.filter(regex = 'calcificationDeleted')), axis = 1, inplace = True)
dfRadRep.drop(list(dfRadRep.filter(regex = 'calcificationDeleted')), axis = 1, inplace = True)

dfRadOri.reset_index(inplace=True)
dfRadRep.reset_index(inplace=True)

iccValues = []
featNames = []
for col in dfRadOri.columns:
    if col == 'StudyPatientName' or col=='index':
        continue
    data = np.stack((dfRadOri[col], dfRadRep[col]), axis=1)
    featNames.append(col)
    iccValues.append(intraclass_correlation(data, "twoway", "agreement").value)
iccDf = pd.DataFrame({'Feature':featNames, 'ICC':iccValues})

iccThreshold = 0.75

reproducibleFeatures = list(iccDf.Feature[iccDf.ICC>iccThreshold])
reproducibleFeatures.append('StudyPatientName')

dfRad = dfRad.filter(reproducibleFeatures)
dfRadTest = dfRadTest.filter(reproducibleFeatures)

# %% [markdown]
# ## Log transform positive skewed parameters

# %%
def makeLog(df, feat, offset=0):
    df[feat+'_log'] = np.log(df[feat]+offset)
    df.drop(feat, axis=1, inplace=True)
    return df

for feat in dfRad.filter(regex='lesion_original', axis=1).columns:
    if skew(dfRad[feat])>3 and np.all(dfRad[feat]>0):
        dfRad = makeLog(dfRad, feat)
        dfRadTest = makeLog(dfRadTest, feat)

# this is heavily skewed, but has minimum value -87
dfRad = makeLog(dfRad, 'lesion_original_glcm_ClusterShade', offset=90)
dfRadTest = makeLog(dfRadTest, 'lesion_original_glcm_ClusterShade', offset=90)

# %%
def featureClassDensities(df_Train, df_Test, featureClass, spSize):
    f,a = plt.subplots(spSize[0], spSize[1], figsize=(20,12))
    a = a.ravel()
    for n, feat in enumerate(df_Train.filter(regex = featureClass, axis = 1).columns):
        df1 = pd.DataFrame(df_Train[feat].copy())
        df1['Data'] = 'train'
        df2 = pd.DataFrame(df_Test[feat].copy())
        df2['Data'] = 'test'
        dfPlot = pd.concat([df1, df2])
        dfPlot.reset_index(drop=True, inplace=True)
        featPlot = feat.replace('lesion_original_' + featureClass + '_','')
        dfPlot.rename(columns={feat:featPlot}, inplace=True)
        sns.kdeplot(data=dfPlot, x=featPlot, hue='Data', ax = a[n], common_grid=True, common_norm=False)

if False:
    featureClassDensities(dfRad.filter(regex='lesion_original'), dfRadTest.filter(regex='lesion_original'), 'shape', (3, 5))
    featureClassDensities(dfRad.filter(regex='lesion_original'), dfRadTest.filter(regex='lesion_original'), 'firstorder', (3,6))
    featureClassDensities(dfRad.filter(regex='lesion_original'), dfRadTest.filter(regex='lesion_original'), 'glcm', (4,6))
    featureClassDensities(dfRad.filter(regex='lesion_original'), dfRadTest.filter(regex='lesion_original'), 'glrlm', (4,4))
    featureClassDensities(dfRad.filter(regex='lesion_original'), dfRadTest.filter(regex='lesion_original'), 'glszm', (4,4))
    featureClassDensities(dfRad.filter(regex='lesion_original'), dfRadTest.filter(regex='lesion_original'), 'gldm', (3,5))
    featureClassDensities(dfRad.filter(regex='lesion_original'), dfRadTest.filter(regex='lesion_original'), 'ngtdm', (2,3))

# %% [markdown]
# ## Run classifications

# %%
def prepData(dfC, dfR, target, featureSet, removeTargetUnknown=True):
    df = dfC.merge(dfR, left_on='Anon Code', right_on='StudyPatientName')
    df.drop('Anon Code', axis=1, inplace=True)
    df.drop('StudyPatientName', axis=1, inplace=True)
    df = df.filter(regex=featureSet + '|' + target)
    if removeTargetUnknown:
        df = df.loc[df[target] != 'Unknown',:]
    return df

def fitModelOrLoadSaved(df, target, settings, qlf):
    
    if os.path.exists(qlf):
        with open(qlf, 'rb') as handle:
            result = pickle.load(handle)
    else:
        result = fit_LR_groupSelection_correlationThresholds(df, target, settings)

        if saveOutputs:
            with open(qlf, 'wb') as handle:
                pickle.dump(result, handle)

    return copy.deepcopy(result)

def showTrainTestResults(result):
    
    # find best model i.e. across all thresholds
    AUROC_cv = np.array([np.mean(x['cv_result']['test_score']) for x in result['experiments']])
    idx = np.argmax(AUROC_cv)
    bestExperiment = result['experiments'][idx]

    trainScore = bestExperiment['model'].predict_proba(df.drop(target, axis=1))
    testScore = bestExperiment['model'].predict_proba(dfTest.drop(target, axis=1))
    
    # get p-value on test data
    classLabels = list(set(dfTest[target]))
    testScores0 = testScore[dfTest[target]==classLabels[0],1]
    testScores1 = testScore[dfTest[target]==classLabels[1],1]
    _, pValue = mannwhitneyu(testScores0, testScores1, alternative='two-sided')
    
    print('AUC')
    print('train #      = ' + str(np.sum(df[target]==classLabels[0])) + ' : ' + str(np.sum(df[target]==classLabels[1])))
    print('train resub  = ' + str(np.round(roc_auc_score(df[target], trainScore[:,1]),3)))
    print('train CV     = ' + str(np.round(np.mean(bestExperiment['cv_result']['test_score']),3)))
    print('\n')
    print('test #       = ' + str(np.sum(dfTest[target]==classLabels[0])) + ' : ' + str(np.sum(dfTest[target]==classLabels[1])))
    print('test         = ' + str(np.round(roc_auc_score(dfTest[target], testScore[:,1]),3)))
    print('test p-value = ' + str(pValue))
    print('\n')
    

defaultSettings = {'n_splits':n_splits, 
                   'n_repeats':n_repeats,
                   'thresholds':thresholds,
                   'penalty':penalty
                   }

# %% [markdown]
# ### Standard radiomics features

# %%
if True:

    resultStandard = {}
    
    for target in ['subtype', 'Grade_1_234', 'Grade_12_34']:
        
        print((target + '_')*10 + '\n')
        
        featureSet = 'lesion_original'

        df = prepData(dfClinical, dfRad, target, featureSet)
        dfTest = prepData(dfClinicalTest, dfRadTest, target, featureSet)
        
        settings = defaultSettings.copy()
        textureStr = 'glcm|gldm|glszm|glrlm|ngtdm'
        settings['groupHierarchy'] = ['shape',
                                      'firstorder',
                                      textureStr,
                                      'shape|firstorder',
                                      'shape|' + textureStr,
                                      'firstorder|' + textureStr,
                                      '']

        quickLoadFile = os.path.join(outputFolder, 'LR_GroupSelection_Standard_' + target + '.pickle')

        resultStandard[target] = fitModelOrLoadSaved(df, target, settings, quickLoadFile)

        if displayAll:
            plotResultExperiments(resultStandard[target], 
                                  titleStr=target + ' standard radiomics features',
                                  outputFile=os.path.join(outputFolder, 'figures', target + '_standard.pdf'))

            bestCoef, pdFreq = displayOneExperiment(resultStandard[target])
            pdFreq = pdFreq.loc[pdFreq.Coef!='',:] # trim off any coeff that aren't in the best model
            display(pdFreq.style.hide_index())

        print('\n'+target)
        showTrainTestResults(resultStandard[target])
# Out:
# subtype_subtype_subtype_subtype_subtype_subtype_subtype_subtype_subtype_subtype_
#
# Threshold = 0.6
# firstorder|texture
# AUROC = 0.872 ± 0.0984
#
# Threshold = 0.62
# firstorder|texture
# AUROC = 0.893 ± 0.0885
#
# Threshold = 0.64
# firstorder|texture
# AUROC = 0.9 ± 0.0838
#
# Threshold = 0.66
# firstorder|texture
# AUROC = 0.902 ± 0.0825
#
# Threshold = 0.68
# firstorder|texture
# AUROC = 0.902 ± 0.0812
#
# Threshold = 0.7
# firstorder|texture
# AUROC = 0.902 ± 0.0811
#
# Threshold = 0.72
# firstorder|texture
# AUROC = 0.902 ± 0.0794
#
# Threshold = 0.74
# firstorder|texture
# AUROC = 0.902 ± 0.0792
#
# Threshold = 0.76
# firstorder|texture
# AUROC = 0.901 ± 0.0794
#
# Threshold = 0.78
# firstorder|texture
# AUROC = 0.901 ± 0.0797
#
# Threshold = 0.8
# firstorder|texture
# AUROC = 0.898 ± 0.0812
#
# Threshold = 0.82
# firstorder|texture
# AUROC = 0.897 ± 0.081
#
# Threshold = 0.84
# firstorder|texture
# AUROC = 0.897 ± 0.0809
#
# Threshold = 0.86
# firstorder|texture
# AUROC = 0.896 ± 0.0812
#
# Threshold = 0.88
# firstorder|texture
# AUROC = 0.894 ± 0.0826
#
# Threshold = 0.9
# all
# AUROC = 0.909 ± 0.0813
#
# Threshold = 0.92
# all
# AUROC = 0.918 ± 0.0764
#
# Threshold = 0.94
# firstorder|texture
# AUROC = 0.92 ± 0.0726
#
# Threshold = 0.96
# firstorder|texture
# AUROC = 0.917 ± 0.0734
#
# Threshold = 0.98
# firstorder|texture
# AUROC = 0.914 ± 0.0731
#
# Threshold = 1.0
# all
# AUROC = 0.916 ± 0.0707
# Threshold = 0.94
# AUROC (CV) = 0.91976
#
# Feature group = firstorder|texture
# <style  type="text/css" >
# </style><table id="T_94749da6_7035_11ed_9393_aa665a01691c" ><thead>    <tr>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Frequency</th>        <th class="col_heading level0 col2" >Coef</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_94749da6_7035_11ed_9393_aa665a01691crow0_col0" class="data row0 col0" >lesion_original_firstorder_Skewness</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow0_col1" class="data row0 col1" >99.000</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow0_col2" class="data row0 col2" >-0.350</td>
#             </tr>
#             <tr>
#                                 <td id="T_94749da6_7035_11ed_9393_aa665a01691crow1_col0" class="data row1 col0" >lesion_original_firstorder_RootMeanSquared</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow1_col1" class="data row1 col1" >89.000</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow1_col2" class="data row1 col2" >-0.422</td>
#             </tr>
#             <tr>
#                                 <td id="T_94749da6_7035_11ed_9393_aa665a01691crow2_col0" class="data row2 col0" >lesion_original_glcm_ClusterProminence_log</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow2_col1" class="data row2 col1" >84.200</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow2_col2" class="data row2 col2" >1.327</td>
#             </tr>
#             <tr>
#                                 <td id="T_94749da6_7035_11ed_9393_aa665a01691crow3_col0" class="data row3 col0" >lesion_original_gldm_SmallDependenceLowGrayLevelEmphasis</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow3_col1" class="data row3 col1" >81.800</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow3_col2" class="data row3 col2" >-1.038</td>
#             </tr>
#             <tr>
#                                 <td id="T_94749da6_7035_11ed_9393_aa665a01691crow4_col0" class="data row4 col0" >lesion_original_glszm_SmallAreaEmphasis</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow4_col1" class="data row4 col1" >76.400</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow4_col2" class="data row4 col2" >0.295</td>
#             </tr>
#             <tr>
#                                 <td id="T_94749da6_7035_11ed_9393_aa665a01691crow5_col0" class="data row5 col0" >lesion_original_glszm_ZonePercentage</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow5_col1" class="data row5 col1" >68.400</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow5_col2" class="data row5 col2" >0.333</td>
#             </tr>
#             <tr>
#                                 <td id="T_94749da6_7035_11ed_9393_aa665a01691crow6_col0" class="data row6 col0" >lesion_original_glcm_Idmn</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow6_col1" class="data row6 col1" >66.800</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow6_col2" class="data row6 col2" >1.015</td>
#             </tr>
#             <tr>
#                                 <td id="T_94749da6_7035_11ed_9393_aa665a01691crow7_col0" class="data row7 col0" >lesion_original_firstorder_Mean</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow7_col1" class="data row7 col1" >65.000</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow7_col2" class="data row7 col2" >-2.877</td>
#             </tr>
#             <tr>
#                                 <td id="T_94749da6_7035_11ed_9393_aa665a01691crow8_col0" class="data row8 col0" >lesion_original_ngtdm_Strength_log</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow8_col1" class="data row8 col1" >63.000</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow8_col2" class="data row8 col2" >-0.469</td>
#             </tr>
#             <tr>
#                                 <td id="T_94749da6_7035_11ed_9393_aa665a01691crow9_col0" class="data row9 col0" >lesion_original_ngtdm_Contrast</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow9_col1" class="data row9 col1" >40.000</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow9_col2" class="data row9 col2" >0.104</td>
#             </tr>
#             <tr>
#                                 <td id="T_94749da6_7035_11ed_9393_aa665a01691crow10_col0" class="data row10 col0" >lesion_original_firstorder_Maximum</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow10_col1" class="data row10 col1" >38.800</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow10_col2" class="data row10 col2" >0.013</td>
#             </tr>
#             <tr>
#                                 <td id="T_94749da6_7035_11ed_9393_aa665a01691crow11_col0" class="data row11 col0" >lesion_original_glszm_LargeAreaHighGrayLevelEmphasis_log</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow11_col1" class="data row11 col1" >18.000</td>
#                         <td id="T_94749da6_7035_11ed_9393_aa665a01691crow11_col2" class="data row11 col2" >-0.042</td>
#             </tr>
#     </tbody></table>
# subtype
# AUC
# train #      = 117 : 53
# train resub  = 0.963
# train CV     = 0.92
#
#
# test #       = 76 : 13
# test         = 0.924
# test p-value = 1.163937490482284e-06
#
#
# Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_
#
# Threshold = 0.6
# firstorder|texture
# AUROC = 0.81 ± 0.1647
#
# Threshold = 0.62
# firstorder|texture
# AUROC = 0.835 ± 0.1475
#
# Threshold = 0.64
# firstorder|texture
# AUROC = 0.85 ± 0.1349
#
# Threshold = 0.66
# firstorder|texture
# AUROC = 0.853 ± 0.1336
#
# Threshold = 0.68
# firstorder|texture
# AUROC = 0.859 ± 0.131
#
# Threshold = 0.7
# firstorder|texture
# AUROC = 0.859 ± 0.1321
#
# Threshold = 0.72
# firstorder|texture
# AUROC = 0.86 ± 0.1321
#
# Threshold = 0.74
# firstorder|texture
# AUROC = 0.86 ± 0.1323
#
# Threshold = 0.76
# firstorder|texture
# AUROC = 0.86 ± 0.1323
#
# Threshold = 0.78
# firstorder|texture
# AUROC = 0.86 ± 0.1318
#
# Threshold = 0.8
# firstorder|texture
# AUROC = 0.863 ± 0.1311
#
# Threshold = 0.82
# firstorder|texture
# AUROC = 0.863 ± 0.1323
#
# Threshold = 0.84
# firstorder|texture
# AUROC = 0.863 ± 0.1318
#
# Threshold = 0.86
# firstorder|texture
# AUROC = 0.863 ± 0.1319
#
# Threshold = 0.88
# firstorder|texture
# AUROC = 0.861 ± 0.1313
#
# Threshold = 0.9
# firstorder|texture
# AUROC = 0.862 ± 0.1311
#
# Threshold = 0.92
# firstorder|texture
# AUROC = 0.863 ± 0.1297
#
# Threshold = 0.94
# firstorder|texture
# AUROC = 0.863 ± 0.131
#
# Threshold = 0.96
# firstorder|texture
# AUROC = 0.86 ± 0.133
#
# Threshold = 0.98
# all
# AUROC = 0.86 ± 0.1305
#
# Threshold = 1.0
# all
# AUROC = 0.857 ± 0.1295
# Threshold = 0.94
# AUROC (CV) = 0.86344
#
# Feature group = firstorder|texture
# <style  type="text/css" >
# </style><table id="T_d2071ecc_703e_11ed_8418_aa665a01691c" ><thead>    <tr>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Frequency</th>        <th class="col_heading level0 col2" >Coef</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow0_col0" class="data row0 col0" >lesion_original_firstorder_90Percentile</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow0_col1" class="data row0 col1" >100.000</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow0_col2" class="data row0 col2" >-1.811</td>
#             </tr>
#             <tr>
#                                 <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow1_col0" class="data row1 col0" >lesion_original_firstorder_RootMeanSquared</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow1_col1" class="data row1 col1" >88.600</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow1_col2" class="data row1 col2" >0.093</td>
#             </tr>
#             <tr>
#                                 <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow2_col0" class="data row2 col0" >lesion_original_gldm_DependenceNonUniformityNormalized_log</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow2_col1" class="data row2 col1" >86.600</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow2_col2" class="data row2 col2" >-0.369</td>
#             </tr>
#             <tr>
#                                 <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow3_col0" class="data row3 col0" >lesion_original_glszm_ZoneVariance_log</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow3_col1" class="data row3 col1" >83.400</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow3_col2" class="data row3 col2" >-0.412</td>
#             </tr>
#             <tr>
#                                 <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow4_col0" class="data row4 col0" >lesion_original_glcm_ClusterShade_log</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow4_col1" class="data row4 col1" >80.800</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow4_col2" class="data row4 col2" >0.192</td>
#             </tr>
#             <tr>
#                                 <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow5_col0" class="data row5 col0" >lesion_original_ngtdm_Strength_log</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow5_col1" class="data row5 col1" >74.600</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow5_col2" class="data row5 col2" >0.136</td>
#             </tr>
#             <tr>
#                                 <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow6_col0" class="data row6 col0" >lesion_original_firstorder_Kurtosis_log</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow6_col1" class="data row6 col1" >71.600</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow6_col2" class="data row6 col2" >0.141</td>
#             </tr>
#             <tr>
#                                 <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow7_col0" class="data row7 col0" >lesion_original_glszm_LargeAreaHighGrayLevelEmphasis_log</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow7_col1" class="data row7 col1" >51.000</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow7_col2" class="data row7 col2" >-0.070</td>
#             </tr>
#             <tr>
#                                 <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow8_col0" class="data row8 col0" >lesion_original_firstorder_InterquartileRange</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow8_col1" class="data row8 col1" >49.400</td>
#                         <td id="T_d2071ecc_703e_11ed_8418_aa665a01691crow8_col2" class="data row8 col2" >-0.016</td>
#             </tr>
#     </tbody></table>
# Grade_1_234
# AUC
# train #      = 132 : 38
# train resub  = 0.909
# train CV     = 0.863
#
#
# test #       = 56 : 33
# test         = 0.824
# test p-value = 3.8701410013537203e-07
#
#
# Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_
#
# Threshold = 0.6
# firstorder
# AUROC = 0.665 ± 0.1713
#
# Threshold = 0.62
# firstorder
# AUROC = 0.704 ± 0.1503
#
# Threshold = 0.64
# firstorder
# AUROC = 0.726 ± 0.1323
#
# Threshold = 0.66
# firstorder
# AUROC = 0.731 ± 0.1209
#
# Threshold = 0.68
# firstorder
# AUROC = 0.73 ± 0.1207
#
# Threshold = 0.7
# firstorder
# AUROC = 0.727 ± 0.1211
#
# Threshold = 0.72
# shape|firstorder
# AUROC = 0.725 ± 0.1221
#
# Threshold = 0.74
# shape|firstorder
# AUROC = 0.723 ± 0.1225
#
# Threshold = 0.76
# shape|firstorder
# AUROC = 0.722 ± 0.1231
#
# Threshold = 0.78
# shape|firstorder
# AUROC = 0.721 ± 0.1233
#
# Threshold = 0.8
# all
# AUROC = 0.719 ± 0.1202
#
# Threshold = 0.82
# all
# AUROC = 0.719 ± 0.1209
#
# Threshold = 0.84
# all
# AUROC = 0.718 ± 0.1205
#
# Threshold = 0.86
# all
# AUROC = 0.718 ± 0.1207
#
# Threshold = 0.88
# all
# AUROC = 0.717 ± 0.1218
#
# Threshold = 0.9
# all
# AUROC = 0.715 ± 0.1217
#
# Threshold = 0.92
# all
# AUROC = 0.711 ± 0.1176
#
# Threshold = 0.94
# all
# AUROC = 0.71 ± 0.1188
#
# Threshold = 0.96
# all
# AUROC = 0.711 ± 0.1201
#
# Threshold = 0.98
# firstorder
# AUROC = 0.715 ± 0.1187
#
# Threshold = 1.0
# firstorder
# AUROC = 0.719 ± 0.1182
# Threshold = 0.66
# AUROC (CV) = 0.73089
#
# Feature group = firstorder
# <style  type="text/css" >
# </style><table id="T_56db992c_7049_11ed_b7e9_aa665a01691c" ><thead>    <tr>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Frequency</th>        <th class="col_heading level0 col2" >Coef</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_56db992c_7049_11ed_b7e9_aa665a01691crow0_col0" class="data row0 col0" >lesion_original_firstorder_90Percentile</td>
#                         <td id="T_56db992c_7049_11ed_b7e9_aa665a01691crow0_col1" class="data row0 col1" >92.800</td>
#                         <td id="T_56db992c_7049_11ed_b7e9_aa665a01691crow0_col2" class="data row0 col2" >-1.089</td>
#             </tr>
#             <tr>
#                                 <td id="T_56db992c_7049_11ed_b7e9_aa665a01691crow1_col0" class="data row1 col0" >lesion_original_firstorder_InterquartileRange</td>
#                         <td id="T_56db992c_7049_11ed_b7e9_aa665a01691crow1_col1" class="data row1 col1" >46.800</td>
#                         <td id="T_56db992c_7049_11ed_b7e9_aa665a01691crow1_col2" class="data row1 col2" >-0.024</td>
#             </tr>
#             <tr>
#                                 <td id="T_56db992c_7049_11ed_b7e9_aa665a01691crow2_col0" class="data row2 col0" >lesion_original_firstorder_Skewness</td>
#                         <td id="T_56db992c_7049_11ed_b7e9_aa665a01691crow2_col1" class="data row2 col1" >42.200</td>
#                         <td id="T_56db992c_7049_11ed_b7e9_aa665a01691crow2_col2" class="data row2 col2" >0.032</td>
#             </tr>
#     </tbody></table>
# Grade_12_34
# AUC
# train #      = 58 : 112
# train resub  = 0.758
# train CV     = 0.731
#
#
# test #       = 23 : 66
# test         = 0.54
# test p-value = 0.5770932798266052

# %% [markdown]
# ### Volume fraction and standard radiomics features

# %%
if True:
    
    resultVolFrac = {}
    
    for target in ['subtype', 'Grade_1_234', 'Grade_12_34']:

        print((target + '_')*10 + '\n')
        
        featureSet = 'lesion_original|VolumeFraction'

        df = prepData(dfClinical, dfRad, target, featureSet)
        dfTest = prepData(dfClinicalTest, dfRadTest, target, featureSet)
        
        # remove one of the volume fraction features as it is co-linear with the others
        df.drop('lesion_sarcomaFeature_mid enhancingVolumeFraction', axis=1, inplace=True)
        dfTest.drop('lesion_sarcomaFeature_mid enhancingVolumeFraction', axis=1, inplace=True)

        settings = defaultSettings.copy()
        textureStr = 'glcm|gldm|glszm|glrlm|ngtdm'
        settings['groupHierarchy'] = ['VolumeFraction',
                                      'shape',
                                      'firstorder',
                                      textureStr,
                                      'VolumeFraction|shape',
                                      'VolumeFraction|firstorder',
                                      'VolumeFraction|' + textureStr,
                                      'shape|firstorder',
                                      'shape|' + textureStr,
                                      'firstorder|' + textureStr,
                                      '']
        settings['correlationHierarchy'] = ['VolumeFraction', 'shape', 'firstorder']

        
        quickLoadFile = os.path.join(outputFolder, 'LR_GroupSelection_VolumeFractions_' + target + '.pickle')

        resultVolFrac[target] = fitModelOrLoadSaved(df, target, settings, quickLoadFile)

        if displayAll:
            plotResultExperiments(resultVolFrac[target], 
                                  titleStr = target + ' volume fraction + standard radiomics features',
                                  outputFile=os.path.join(outputFolder, 'figures', target+'_standard_volFrac.pdf'))


            bestCoef, pdFreq = displayOneExperiment(resultVolFrac[target])
            pdFreq = pdFreq.loc[pdFreq.Coef!='',:] # trim off any coeff that aren't in the best model
            display(pdFreq.style.hide_index())

        print('\n'+target)
        showTrainTestResults(resultVolFrac[target])
# Out:
# subtype_subtype_subtype_subtype_subtype_subtype_subtype_subtype_subtype_subtype_
#
# Threshold = 0.6
# VolumeFraction|shape
# AUROC = 0.868 ± 0.092
#
# Threshold = 0.62
# VolumeFraction|shape
# AUROC = 0.867 ± 0.0923
#
# Threshold = 0.64
# VolumeFraction|shape
# AUROC = 0.866 ± 0.0923
#
# Threshold = 0.66
# VolumeFraction|shape
# AUROC = 0.869 ± 0.0905
#
# Threshold = 0.68
# VolumeFraction|shape
# AUROC = 0.873 ± 0.0881
#
# Threshold = 0.7
# VolumeFraction|shape
# AUROC = 0.875 ± 0.0878
#
# Threshold = 0.72
# VolumeFraction|shape
# AUROC = 0.876 ± 0.0884
#
# Threshold = 0.74
# firstorder|texture
# AUROC = 0.878 ± 0.086
#
# Threshold = 0.76
# VolumeFraction|texture
# AUROC = 0.881 ± 0.0826
#
# Threshold = 0.78
# VolumeFraction|texture
# AUROC = 0.878 ± 0.0825
#
# Threshold = 0.8
# VolumeFraction|shape
# AUROC = 0.883 ± 0.0846
#
# Threshold = 0.82
# VolumeFraction|texture
# AUROC = 0.908 ± 0.0786
#
# Threshold = 0.84
# VolumeFraction|texture
# AUROC = 0.912 ± 0.0774
#
# Threshold = 0.86
# VolumeFraction|texture
# AUROC = 0.911 ± 0.0781
#
# Threshold = 0.88
# VolumeFraction|texture
# AUROC = 0.907 ± 0.0792
#
# Threshold = 0.9
# all
# AUROC = 0.893 ± 0.0763
#
# Threshold = 0.92
# all
# AUROC = 0.896 ± 0.0766
#
# Threshold = 0.94
# firstorder|texture
# AUROC = 0.91 ± 0.0734
#
# Threshold = 0.96
# firstorder|texture
# AUROC = 0.908 ± 0.0754
#
# Threshold = 0.98
# firstorder|texture
# AUROC = 0.908 ± 0.074
#
# Threshold = 1.0
# firstorder|texture
# AUROC = 0.911 ± 0.073
# Threshold = 0.84
# AUROC (CV) = 0.9118
#
# Feature group = VolumeFraction|texture
# <style  type="text/css" >
# </style><table id="T_857c0390_7056_11ed_9cd3_aa665a01691c" ><thead>    <tr>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Frequency</th>        <th class="col_heading level0 col2" >Coef</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow0_col0" class="data row0 col0" >lesion_sarcomaFeature_high enhancingVolumeFraction</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow0_col1" class="data row0 col1" >95.400</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow0_col2" class="data row0 col2" >-0.668</td>
#             </tr>
#             <tr>
#                                 <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow1_col0" class="data row1 col0" >lesion_sarcomaFeature_low enhancingVolumeFraction</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow1_col1" class="data row1 col1" >95.400</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow1_col2" class="data row1 col2" >7.548</td>
#             </tr>
#             <tr>
#                                 <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow2_col0" class="data row2 col0" >lesion_original_glszm_SmallAreaEmphasis</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow2_col1" class="data row2 col1" >88.800</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow2_col2" class="data row2 col2" >0.540</td>
#             </tr>
#             <tr>
#                                 <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow3_col0" class="data row3 col0" >lesion_original_gldm_SmallDependenceLowGrayLevelEmphasis</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow3_col1" class="data row3 col1" >88.800</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow3_col2" class="data row3 col2" >-4.830</td>
#             </tr>
#             <tr>
#                                 <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow4_col0" class="data row4 col0" >lesion_original_glszm_ZonePercentage</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow4_col1" class="data row4 col1" >87.400</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow4_col2" class="data row4 col2" >2.044</td>
#             </tr>
#             <tr>
#                                 <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow5_col0" class="data row5 col0" >lesion_original_glszm_ZoneEntropy</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow5_col1" class="data row5 col1" >87.200</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow5_col2" class="data row5 col2" >0.563</td>
#             </tr>
#             <tr>
#                                 <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow6_col0" class="data row6 col0" >lesion_original_glszm_LargeAreaHighGrayLevelEmphasis_log</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow6_col1" class="data row6 col1" >86.800</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow6_col2" class="data row6 col2" >-4.108</td>
#             </tr>
#             <tr>
#                                 <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow7_col0" class="data row7 col0" >lesion_original_ngtdm_Strength_log</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow7_col1" class="data row7 col1" >85.800</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow7_col2" class="data row7 col2" >0.442</td>
#             </tr>
#             <tr>
#                                 <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow8_col0" class="data row8 col0" >lesion_original_glszm_ZoneVariance_log</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow8_col1" class="data row8 col1" >85.000</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow8_col2" class="data row8 col2" >5.096</td>
#             </tr>
#             <tr>
#                                 <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow9_col0" class="data row9 col0" >lesion_original_ngtdm_Contrast</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow9_col1" class="data row9 col1" >84.200</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow9_col2" class="data row9 col2" >0.411</td>
#             </tr>
#             <tr>
#                                 <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow10_col0" class="data row10 col0" >lesion_original_gldm_DependenceVariance</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow10_col1" class="data row10 col1" >81.000</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow10_col2" class="data row10 col2" >-0.195</td>
#             </tr>
#             <tr>
#                                 <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow11_col0" class="data row11 col0" >lesion_original_gldm_DependenceNonUniformityNormalized_log</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow11_col1" class="data row11 col1" >79.800</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow11_col2" class="data row11 col2" >-0.085</td>
#             </tr>
#             <tr>
#                                 <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow12_col0" class="data row12 col0" >lesion_sarcomaFeature_calcificationVolumeFraction</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow12_col1" class="data row12 col1" >70.600</td>
#                         <td id="T_857c0390_7056_11ed_9cd3_aa665a01691crow12_col2" class="data row12 col2" >0.073</td>
#             </tr>
#     </tbody></table>
# subtype
# AUC
# train #      = 117 : 53
# train resub  = 0.96
# train CV     = 0.912
#
#
# test #       = 76 : 13
# test         = 0.928
# test p-value = 9.194067936547276e-07
#
#
# Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_
#
# Threshold = 0.6
# all
# AUROC = 0.81 ± 0.1531
#
# Threshold = 0.62
# all
# AUROC = 0.807 ± 0.153
#
# Threshold = 0.64
# all
# AUROC = 0.806 ± 0.1536
#
# Threshold = 0.66
# all
# AUROC = 0.806 ± 0.154
#
# Threshold = 0.68
# VolumeFraction|firstorder
# AUROC = 0.806 ± 0.1525
#
# Threshold = 0.7
# VolumeFraction|firstorder
# AUROC = 0.803 ± 0.1534
#
# Threshold = 0.72
# all
# AUROC = 0.805 ± 0.1544
#
# Threshold = 0.74
# firstorder|texture
# AUROC = 0.83 ± 0.1497
#
# Threshold = 0.76
# firstorder|texture
# AUROC = 0.849 ± 0.1371
#
# Threshold = 0.78
# firstorder|texture
# AUROC = 0.852 ± 0.1346
#
# Threshold = 0.8
# firstorder|texture
# AUROC = 0.855 ± 0.1344
#
# Threshold = 0.82
# firstorder|texture
# AUROC = 0.856 ± 0.1347
#
# Threshold = 0.84
# firstorder|texture
# AUROC = 0.857 ± 0.1339
#
# Threshold = 0.86
# firstorder|texture
# AUROC = 0.858 ± 0.1339
#
# Threshold = 0.88
# firstorder|texture
# AUROC = 0.858 ± 0.1329
#
# Threshold = 0.9
# firstorder|texture
# AUROC = 0.855 ± 0.1344
#
# Threshold = 0.92
# firstorder|texture
# AUROC = 0.856 ± 0.1335
#
# Threshold = 0.94
# firstorder|texture
# AUROC = 0.854 ± 0.1331
#
# Threshold = 0.96
# firstorder|texture
# AUROC = 0.848 ± 0.1354
#
# Threshold = 0.98
# all
# AUROC = 0.85 ± 0.1332
#
# Threshold = 1.0
# firstorder|texture
# AUROC = 0.844 ± 0.1353
# Threshold = 0.86
# AUROC (CV) = 0.85846
#
# Feature group = firstorder|texture
# <style  type="text/css" >
# </style><table id="T_cbd0083e_7063_11ed_9c9d_aa665a01691c" ><thead>    <tr>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Frequency</th>        <th class="col_heading level0 col2" >Coef</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow0_col0" class="data row0 col0" >lesion_original_firstorder_90Percentile</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow0_col1" class="data row0 col1" >89.000</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow0_col2" class="data row0 col2" >-1.784</td>
#             </tr>
#             <tr>
#                                 <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow1_col0" class="data row1 col0" >lesion_original_gldm_DependenceNonUniformityNormalized_log</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow1_col1" class="data row1 col1" >86.800</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow1_col2" class="data row1 col2" >-0.388</td>
#             </tr>
#             <tr>
#                                 <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow2_col0" class="data row2 col0" >lesion_original_firstorder_RootMeanSquared</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow2_col1" class="data row2 col1" >85.000</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow2_col2" class="data row2 col2" >0.136</td>
#             </tr>
#             <tr>
#                                 <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow3_col0" class="data row3 col0" >lesion_original_glszm_ZoneVariance_log</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow3_col1" class="data row3 col1" >79.600</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow3_col2" class="data row3 col2" >-0.425</td>
#             </tr>
#             <tr>
#                                 <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow4_col0" class="data row4 col0" >lesion_original_firstorder_Kurtosis_log</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow4_col1" class="data row4 col1" >77.000</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow4_col2" class="data row4 col2" >0.199</td>
#             </tr>
#             <tr>
#                                 <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow5_col0" class="data row5 col0" >lesion_original_ngtdm_Strength_log</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow5_col1" class="data row5 col1" >71.600</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow5_col2" class="data row5 col2" >0.121</td>
#             </tr>
#             <tr>
#                                 <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow6_col0" class="data row6 col0" >lesion_original_firstorder_Skewness</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow6_col1" class="data row6 col1" >62.400</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow6_col2" class="data row6 col2" >0.049</td>
#             </tr>
#             <tr>
#                                 <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow7_col0" class="data row7 col0" >lesion_original_glszm_LargeAreaHighGrayLevelEmphasis_log</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow7_col1" class="data row7 col1" >58.800</td>
#                         <td id="T_cbd0083e_7063_11ed_9c9d_aa665a01691crow7_col2" class="data row7 col2" >-0.079</td>
#             </tr>
#     </tbody></table>
# Grade_1_234
# AUC
# train #      = 132 : 38
# train resub  = 0.907
# train CV     = 0.858
#
#
# test #       = 56 : 33
# test         = 0.832
# test p-value = 1.8768118648265188e-07
#
#
# Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_
#
# Threshold = 0.6
# VolumeFraction|firstorder
# AUROC = 0.689 ± 0.1222
#
# Threshold = 0.62
# VolumeFraction|firstorder
# AUROC = 0.69 ± 0.1204
#
# Threshold = 0.64
# VolumeFraction|firstorder
# AUROC = 0.689 ± 0.1207
#
# Threshold = 0.66
# VolumeFraction|firstorder
# AUROC = 0.689 ± 0.1208
#
# Threshold = 0.68
# VolumeFraction|firstorder
# AUROC = 0.689 ± 0.1203
#
# Threshold = 0.7
# VolumeFraction|firstorder
# AUROC = 0.687 ± 0.1195
#
# Threshold = 0.72
# VolumeFraction|firstorder
# AUROC = 0.685 ± 0.1194
#
# Threshold = 0.74
# VolumeFraction|firstorder
# AUROC = 0.697 ± 0.1247
#
# Threshold = 0.76
# VolumeFraction|firstorder
# AUROC = 0.706 ± 0.1214
#
# Threshold = 0.78
# VolumeFraction|firstorder
# AUROC = 0.707 ± 0.1205
#
# Threshold = 0.8
# firstorder|texture
# AUROC = 0.707 ± 0.1216
#
# Threshold = 0.82
# firstorder|texture
# AUROC = 0.708 ± 0.1219
#
# Threshold = 0.84
# firstorder|texture
# AUROC = 0.708 ± 0.1209
#
# Threshold = 0.86
# firstorder|texture
# AUROC = 0.71 ± 0.1214
#
# Threshold = 0.88
# firstorder|texture
# AUROC = 0.709 ± 0.1197
#
# Threshold = 0.9
# firstorder|texture
# AUROC = 0.707 ± 0.1179
#
# Threshold = 0.92
# VolumeFraction|firstorder
# AUROC = 0.7 ± 0.1203
#
# Threshold = 0.94
# VolumeFraction|firstorder
# AUROC = 0.702 ± 0.1219
#
# Threshold = 0.96
# VolumeFraction|firstorder
# AUROC = 0.702 ± 0.1206
#
# Threshold = 0.98
# all
# AUROC = 0.706 ± 0.1172
#
# Threshold = 1.0
# firstorder
# AUROC = 0.711 ± 0.119
# Threshold = 1.0
# AUROC (CV) = 0.71092
#
# Feature group = firstorder
# <style  type="text/css" >
# </style><table id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691c" ><thead>    <tr>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Frequency</th>        <th class="col_heading level0 col2" >Coef</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow0_col0" class="data row0 col0" >lesion_original_firstorder_TotalEnergy_log</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow0_col1" class="data row0 col1" >87.400</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow0_col2" class="data row0 col2" >-0.233</td>
#             </tr>
#             <tr>
#                                 <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow1_col0" class="data row1 col0" >lesion_original_firstorder_Energy_log</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow1_col1" class="data row1 col1" >87.200</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow1_col2" class="data row1 col2" >-0.135</td>
#             </tr>
#             <tr>
#                                 <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow2_col0" class="data row2 col0" >lesion_original_firstorder_10Percentile</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow2_col1" class="data row2 col1" >69.400</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow2_col2" class="data row2 col2" >-1.370</td>
#             </tr>
#             <tr>
#                                 <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow3_col0" class="data row3 col0" >lesion_original_firstorder_RobustMeanAbsoluteDeviation</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow3_col1" class="data row3 col1" >68.400</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow3_col2" class="data row3 col2" >-1.124</td>
#             </tr>
#             <tr>
#                                 <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow4_col0" class="data row4 col0" >lesion_original_firstorder_Variance_log</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow4_col1" class="data row4 col1" >66.400</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow4_col2" class="data row4 col2" >0.535</td>
#             </tr>
#             <tr>
#                                 <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow5_col0" class="data row5 col0" >lesion_original_firstorder_Range</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow5_col1" class="data row5 col1" >48.800</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow5_col2" class="data row5 col2" >-0.268</td>
#             </tr>
#             <tr>
#                                 <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow6_col0" class="data row6 col0" >lesion_original_firstorder_Maximum</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow6_col1" class="data row6 col1" >45.600</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow6_col2" class="data row6 col2" >0.192</td>
#             </tr>
#             <tr>
#                                 <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow7_col0" class="data row7 col0" >lesion_original_firstorder_Uniformity</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow7_col1" class="data row7 col1" >35.000</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow7_col2" class="data row7 col2" >0.094</td>
#             </tr>
#             <tr>
#                                 <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow8_col0" class="data row8 col0" >lesion_original_firstorder_Median</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow8_col1" class="data row8 col1" >34.000</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow8_col2" class="data row8 col2" >-0.236</td>
#             </tr>
#             <tr>
#                                 <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow9_col0" class="data row9 col0" >lesion_original_firstorder_Mean</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow9_col1" class="data row9 col1" >23.200</td>
#                         <td id="T_0cc0e6a6_7073_11ed_b4ae_aa665a01691crow9_col2" class="data row9 col2" >-0.062</td>
#             </tr>
#     </tbody></table>
# Grade_12_34
# AUC
# train #      = 58 : 112
# train resub  = 0.803
# train CV     = 0.711
#
#
# test #       = 23 : 66
# test         = 0.58
# test p-value = 0.25875901804530455

# %% [markdown]
# ### Approx volume fraction and standard radiomics features

# %%
if True:
    
    resultApproxVolFrac = {}
    
    for target in ['subtype', 'Grade_1_234', 'Grade_12_34']:

        print((target + '_')*5 + '\n')
        
        featureSet = 'lesion_original|ApproxVolFraction'

        df = prepData(dfClinical, dfRad, target, featureSet)
        dfTest = prepData(dfClinicalTest, dfRadTest, target, featureSet)

        settings = defaultSettings.copy()
        textureStr = 'glcm|gldm|glszm|glrlm|ngtdm'
        settings['groupHierarchy'] = ['ApproxVolFraction',
                                      'shape',
                                      'firstorder',
                                      textureStr,
                                      'ApproxVolFraction|shape',
                                      'ApproxVolFraction|firstorder',
                                      'ApproxVolFraction|' + textureStr,
                                      'shape|firstorder',
                                      'shape|' + textureStr,
                                      'firstorder|' + textureStr,
                                      '']
        settings['correlationHierarchy'] = ['ApproxVolFraction', 'shape', 'firstorder']
        
        quickLoadFile = os.path.join(outputFolder, 'LR_GroupSelection_ApproxVolFraction_' + target + '.pickle')

        resultApproxVolFrac[target] = fitModelOrLoadSaved(df, target, settings, quickLoadFile)

        if displayAll:
            plotResultExperiments(resultApproxVolFrac[target], 
                                  titleStr = target + ' approx volume fraction + standard radiomics features',
                                  outputFile=os.path.join(outputFolder, 'figures', target+'_approx_volFrac.pdf'))


            bestCoef, pdFreq = displayOneExperiment(resultApproxVolFrac[target])
            pdFreq = pdFreq.loc[pdFreq.Coef!='',:] # trim off any coeff that aren't in the best model
            display(pdFreq.style.hide_index())

        print('\n'+target)
        showTrainTestResults(resultApproxVolFrac[target])
# Out:
# subtype_subtype_subtype_subtype_subtype_
#
# Threshold = 0.6
# ApproxVolFraction|texture
# AUROC = 0.942 ± 0.0556
#
# Threshold = 0.62
# ApproxVolFraction|texture
# AUROC = 0.943 ± 0.0547
#
# Threshold = 0.64
# ApproxVolFraction|texture
# AUROC = 0.943 ± 0.0543
#
# Threshold = 0.66
# ApproxVolFraction|texture
# AUROC = 0.943 ± 0.0541
#
# Threshold = 0.68
# ApproxVolFraction|texture
# AUROC = 0.939 ± 0.0555
#
# Threshold = 0.7
# ApproxVolFraction|texture
# AUROC = 0.938 ± 0.0565
#
# Threshold = 0.72
# ApproxVolFraction|texture
# AUROC = 0.938 ± 0.0568
#
# Threshold = 0.74
# ApproxVolFraction|texture
# AUROC = 0.938 ± 0.0576
#
# Threshold = 0.76
# ApproxVolFraction|texture
# AUROC = 0.938 ± 0.0576
#
# Threshold = 0.78
# ApproxVolFraction|texture
# AUROC = 0.937 ± 0.0576
#
# Threshold = 0.8
# ApproxVolFraction|texture
# AUROC = 0.935 ± 0.059
#
# Threshold = 0.82
# ApproxVolFraction|texture
# AUROC = 0.933 ± 0.0602
#
# Threshold = 0.84
# ApproxVolFraction|texture
# AUROC = 0.933 ± 0.0608
#
# Threshold = 0.86
# ApproxVolFraction|texture
# AUROC = 0.933 ± 0.0606
#
# Threshold = 0.88
# ApproxVolFraction|texture
# AUROC = 0.93 ± 0.0624
#
# Threshold = 0.9
# ApproxVolFraction|texture
# AUROC = 0.932 ± 0.0621
#
# Threshold = 0.92
# ApproxVolFraction|texture
# AUROC = 0.931 ± 0.0623
#
# Threshold = 0.94
# ApproxVolFraction|texture
# AUROC = 0.926 ± 0.0642
#
# Threshold = 0.96
# ApproxVolFraction|texture
# AUROC = 0.921 ± 0.0667
#
# Threshold = 0.98
# ApproxVolFraction|texture
# AUROC = 0.915 ± 0.0707
#
# Threshold = 1.0
# ApproxVolFraction|texture
# AUROC = 0.911 ± 0.0705
# Threshold = 0.64
# AUROC (CV) = 0.94342
#
# Feature group = ApproxVolFraction|texture
# <style  type="text/css" >
# </style><table id="T_a649c564_7081_11ed_b0fd_aa665a01691c" ><thead>    <tr>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Frequency</th>        <th class="col_heading level0 col2" >Coef</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow0_col0" class="data row0 col0" >lesion_sarcomaFeature_calcApproxVolFraction</td>
#                         <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow0_col1" class="data row0 col1" >99.800</td>
#                         <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow0_col2" class="data row0 col2" >0.661</td>
#             </tr>
#             <tr>
#                                 <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow1_col0" class="data row1 col0" >lesion_original_gldm_SmallDependenceLowGrayLevelEmphasis</td>
#                         <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow1_col1" class="data row1 col1" >97.400</td>
#                         <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow1_col2" class="data row1 col2" >-2.411</td>
#             </tr>
#             <tr>
#                                 <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow2_col0" class="data row2 col0" >lesion_original_glszm_SmallAreaEmphasis</td>
#                         <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow2_col1" class="data row2 col1" >97.200</td>
#                         <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow2_col2" class="data row2 col2" >0.373</td>
#             </tr>
#             <tr>
#                                 <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow3_col0" class="data row3 col0" >lesion_sarcomaFeature_highApproxVolFraction</td>
#                         <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow3_col1" class="data row3 col1" >96.600</td>
#                         <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow3_col2" class="data row3 col2" >-4.782</td>
#             </tr>
#             <tr>
#                                 <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow4_col0" class="data row4 col0" >lesion_original_ngtdm_Strength_log</td>
#                         <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow4_col1" class="data row4 col1" >92.400</td>
#                         <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow4_col2" class="data row4 col2" >0.208</td>
#             </tr>
#             <tr>
#                                 <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow5_col0" class="data row5 col0" >lesion_original_gldm_DependenceNonUniformityNormalized_log</td>
#                         <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow5_col1" class="data row5 col1" >91.200</td>
#                         <td id="T_a649c564_7081_11ed_b0fd_aa665a01691crow5_col2" class="data row5 col2" >0.129</td>
#             </tr>
#     </tbody></table>
# subtype
# AUC
# train #      = 117 : 53
# train resub  = 0.957
# train CV     = 0.943
#
#
# test #       = 76 : 13
# test         = 0.928
# test p-value = 9.194067936547276e-07
#
#
# Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_Grade_1_234_
#
# Threshold = 0.6
# all
# AUROC = 0.853 ± 0.1266
#
# Threshold = 0.62
# all
# AUROC = 0.854 ± 0.1264
#
# Threshold = 0.64
# all
# AUROC = 0.854 ± 0.1265
#
# Threshold = 0.66
# all
# AUROC = 0.854 ± 0.1273
#
# Threshold = 0.68
# all
# AUROC = 0.854 ± 0.1283
#
# Threshold = 0.7
# all
# AUROC = 0.853 ± 0.1283
#
# Threshold = 0.72
# all
# AUROC = 0.853 ± 0.1273
#
# Threshold = 0.74
# all
# AUROC = 0.852 ± 0.1281
#
# Threshold = 0.76
# all
# AUROC = 0.852 ± 0.1285
#
# Threshold = 0.78
# all
# AUROC = 0.852 ± 0.1278
#
# Threshold = 0.8
# all
# AUROC = 0.851 ± 0.1285
#
# Threshold = 0.82
# all
# AUROC = 0.851 ± 0.1282
#
# Threshold = 0.84
# all
# AUROC = 0.851 ± 0.1283
#
# Threshold = 0.86
# all
# AUROC = 0.85 ± 0.1292
#
# Threshold = 0.88
# firstorder|texture
# AUROC = 0.855 ± 0.132
#
# Threshold = 0.9
# ApproxVolFraction|texture
# AUROC = 0.858 ± 0.1316
#
# Threshold = 0.92
# ApproxVolFraction|texture
# AUROC = 0.854 ± 0.1318
#
# Threshold = 0.94
# ApproxVolFraction|texture
# AUROC = 0.853 ± 0.131
#
# Threshold = 0.96
# ApproxVolFraction|texture
# AUROC = 0.848 ± 0.1328
#
# Threshold = 0.98
# ApproxVolFraction|texture
# AUROC = 0.845 ± 0.1344
#
# Threshold = 1.0
# all
# AUROC = 0.838 ± 0.137
# Threshold = 0.9
# AUROC (CV) = 0.85768
#
# Feature group = ApproxVolFraction|texture
# <style  type="text/css" >
# </style><table id="T_2eb7aea4_708f_11ed_8e17_aa665a01691c" ><thead>    <tr>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Frequency</th>        <th class="col_heading level0 col2" >Coef</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow0_col0" class="data row0 col0" >lesion_original_gldm_DependenceNonUniformityNormalized_log</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow0_col1" class="data row0 col1" >86.800</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow0_col2" class="data row0 col2" >-0.505</td>
#             </tr>
#             <tr>
#                                 <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow1_col0" class="data row1 col0" >lesion_original_ngtdm_Strength_log</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow1_col1" class="data row1 col1" >83.400</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow1_col2" class="data row1 col2" >0.423</td>
#             </tr>
#             <tr>
#                                 <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow2_col0" class="data row2 col0" >lesion_original_glszm_LargeAreaHighGrayLevelEmphasis_log</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow2_col1" class="data row2 col1" >75.000</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow2_col2" class="data row2 col2" >-0.367</td>
#             </tr>
#             <tr>
#                                 <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow3_col0" class="data row3 col0" >lesion_original_glszm_ZoneVariance_log</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow3_col1" class="data row3 col1" >69.000</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow3_col2" class="data row3 col2" >-0.231</td>
#             </tr>
#             <tr>
#                                 <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow4_col0" class="data row4 col0" >lesion_sarcomaFeature_highApproxVolFraction</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow4_col1" class="data row4 col1" >67.800</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow4_col2" class="data row4 col2" >-2.066</td>
#             </tr>
#             <tr>
#                                 <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow5_col0" class="data row5 col0" >lesion_original_glcm_MaximumProbability</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow5_col1" class="data row5 col1" >62.200</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow5_col2" class="data row5 col2" >1.016</td>
#             </tr>
#             <tr>
#                                 <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow6_col0" class="data row6 col0" >lesion_original_glszm_ZonePercentage</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow6_col1" class="data row6 col1" >60.800</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow6_col2" class="data row6 col2" >0.273</td>
#             </tr>
#             <tr>
#                                 <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow7_col0" class="data row7 col0" >lesion_sarcomaFeature_lowApproxVolFraction</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow7_col1" class="data row7 col1" >50.600</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow7_col2" class="data row7 col2" >0.090</td>
#             </tr>
#             <tr>
#                                 <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow8_col0" class="data row8 col0" >lesion_original_glcm_Imc2</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow8_col1" class="data row8 col1" >48.200</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow8_col2" class="data row8 col2" >-0.087</td>
#             </tr>
#             <tr>
#                                 <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow9_col0" class="data row9 col0" >lesion_original_ngtdm_Contrast</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow9_col1" class="data row9 col1" >33.800</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow9_col2" class="data row9 col2" >-0.055</td>
#             </tr>
#             <tr>
#                                 <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow10_col0" class="data row10 col0" >lesion_sarcomaFeature_calcApproxVolFraction</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow10_col1" class="data row10 col1" >32.000</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow10_col2" class="data row10 col2" >0.019</td>
#             </tr>
#             <tr>
#                                 <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow11_col0" class="data row11 col0" >lesion_original_gldm_DependenceVariance</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow11_col1" class="data row11 col1" >24.200</td>
#                         <td id="T_2eb7aea4_708f_11ed_8e17_aa665a01691crow11_col2" class="data row11 col2" >-0.044</td>
#             </tr>
#     </tbody></table>
# Grade_1_234
# AUC
# train #      = 132 : 38
# train resub  = 0.914
# train CV     = 0.858
#
#
# test #       = 56 : 33
# test         = 0.802
# test p-value = 2.0957410113186948e-06
#
#
# Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_Grade_12_34_
#
# Threshold = 0.6
# ApproxVolFraction|firstorder
# AUROC = 0.729 ± 0.1243
#
# Threshold = 0.62
# ApproxVolFraction|firstorder
# AUROC = 0.729 ± 0.1209
#
# Threshold = 0.64
# ApproxVolFraction|firstorder
# AUROC = 0.729 ± 0.1213
#
# Threshold = 0.66
# ApproxVolFraction|firstorder
# AUROC = 0.728 ± 0.1222
#
# Threshold = 0.68
# ApproxVolFraction|firstorder
# AUROC = 0.727 ± 0.1225
#
# Threshold = 0.7
# ApproxVolFraction|firstorder
# AUROC = 0.728 ± 0.1224
#
# Threshold = 0.72
# ApproxVolFraction|firstorder
# AUROC = 0.729 ± 0.1212
#
# Threshold = 0.74
# ApproxVolFraction|firstorder
# AUROC = 0.728 ± 0.121
#
# Threshold = 0.76
# ApproxVolFraction|firstorder
# AUROC = 0.727 ± 0.1213
#
# Threshold = 0.78
# ApproxVolFraction|firstorder
# AUROC = 0.723 ± 0.1204
#
# Threshold = 0.8
# all
# AUROC = 0.714 ± 0.1163
#
# Threshold = 0.82
# all
# AUROC = 0.712 ± 0.1121
#
# Threshold = 0.84
# all
# AUROC = 0.712 ± 0.1124
#
# Threshold = 0.86
# all
# AUROC = 0.712 ± 0.1145
#
# Threshold = 0.88
# firstorder|texture
# AUROC = 0.708 ± 0.1191
#
# Threshold = 0.9
# ApproxVolFraction|texture
# AUROC = 0.706 ± 0.1191
#
# Threshold = 0.92
# ApproxVolFraction|texture
# AUROC = 0.703 ± 0.1169
#
# Threshold = 0.94
# ApproxVolFraction|texture
# AUROC = 0.7 ± 0.1175
#
# Threshold = 0.96
# ApproxVolFraction|texture
# AUROC = 0.704 ± 0.1177
#
# Threshold = 0.98
# ApproxVolFraction|texture
# AUROC = 0.704 ± 0.1133
#
# Threshold = 1.0
# firstorder
# AUROC = 0.708 ± 0.1134
# Threshold = 0.64
# AUROC (CV) = 0.72915
#
# Feature group = ApproxVolFraction|firstorder
# <style  type="text/css" >
# </style><table id="T_17ebee42_709e_11ed_b674_aa665a01691c" ><thead>    <tr>        <th class="col_heading level0 col0" >Feature</th>        <th class="col_heading level0 col1" >Frequency</th>        <th class="col_heading level0 col2" >Coef</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_17ebee42_709e_11ed_b674_aa665a01691crow0_col0" class="data row0 col0" >lesion_sarcomaFeature_highApproxVolFraction</td>
#                         <td id="T_17ebee42_709e_11ed_b674_aa665a01691crow0_col1" class="data row0 col1" >93.800</td>
#                         <td id="T_17ebee42_709e_11ed_b674_aa665a01691crow0_col2" class="data row0 col2" >-1.144</td>
#             </tr>
#             <tr>
#                                 <td id="T_17ebee42_709e_11ed_b674_aa665a01691crow1_col0" class="data row1 col0" >lesion_sarcomaFeature_calcApproxVolFraction</td>
#                         <td id="T_17ebee42_709e_11ed_b674_aa665a01691crow1_col1" class="data row1 col1" >90.400</td>
#                         <td id="T_17ebee42_709e_11ed_b674_aa665a01691crow1_col2" class="data row1 col2" >0.096</td>
#             </tr>
#             <tr>
#                                 <td id="T_17ebee42_709e_11ed_b674_aa665a01691crow2_col0" class="data row2 col0" >lesion_original_firstorder_InterquartileRange</td>
#                         <td id="T_17ebee42_709e_11ed_b674_aa665a01691crow2_col1" class="data row2 col1" >79.200</td>
#                         <td id="T_17ebee42_709e_11ed_b674_aa665a01691crow2_col2" class="data row2 col2" >-0.485</td>
#             </tr>
#     </tbody></table>
# Grade_12_34
# AUC
# train #      = 58 : 112
# train resub  = 0.78
# train CV     = 0.729
#
#
# test #       = 23 : 66
# test         = 0.571
# test p-value = 0.31369802086344745

# %% [markdown]
# ## Re-save the copy of this notebook once it is completed

# %%
from IPython.display import display, Javascript
import time

# save current state of notebook and wait a bit as the actual save happens with a short delay
display(Javascript('IPython.notebook.save_checkpoint();'))
time.sleep(10)

# copy notebook to output folder
if saveOutputs:
    jupyterFile = os.path.join(os.path.abspath(""), 'LR_GroupSelection_withValidation.ipynb')
    shutil.copyfile(jupyterFile, os.path.join(outputFolder, 'code', 'LR_GroupSelection_withValidation.ipynb'))
